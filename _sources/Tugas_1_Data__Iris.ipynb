# %% [markdown]
# #**Tugas 1 Data Iris**

# %% [markdown]
# #**Buat database iris di MySQL dan posgresql dan ditarik pakai power BI**

# %% [markdown]
# #**Database iris di MySQL**
# ---
#
#
# *   **Buka "Get data" maka akan memunculkan opsi seperti di bawah ini. Pada bagian "Database" pilih opsi "MySQL" dan connect kan.**
#
# ![Screenshot 2025-09-07 223745.png](data:image/png;base64,...)
#
# ![Screenshot 2025-09-07 224027.png](data:image/png;base64,...)
#
#
# ---
# *   **Setelah "connect" kan data maka langkah selanjutnya adalah memasukkan server dan database yaitu localhost dan iris, selanjutnya memilih data yang akan di upload.**
# ![Screenshot 2025-09-07 230027.png](data:image/png;base64,...)
#
# ![WhatsApp Image 2025-09-07 at 23.31.04_95edd51e.jpg](data:image/jpeg;base64,...)
#
# ![WhatsApp Image 2025-09-07 at 23.43.56_c6177e4c.jpg](data:image/jpeg;base64,...)
#
#
# ---
# *   **Setelah load data maka akan muncul tampilan seperti di bawah ini.**
# ![Screenshot 2025-09-07 233520.png](data:image/png;base64,...)

# %% [markdown]
# #**Data sudah dieksplorasi data**

# %% [markdown]
# #**Data iris MySQL**
# ---
#
#
# *   **min max dari setiap kolom**
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ---
#
# *   **rata rata dari setiap kolom**
#
# ![image.png](data:image/png;base64,...)
#
#
# ---
#
#
# *   **jumlah setiap kelas ditampilkan dalam grafik batang**
#
# ![image.png](data:image/png;base64,...)
#
# ---

# %% [markdown]
# #**Database iris di posgresql**
